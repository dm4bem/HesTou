# %% [markdown]
# # Run Python script

# %%
# %run pd05simulation.py
# Out:
# Time step: = 7200 s = 2.0 h
# Mean outdoor temperature: 7.4 °C
# Min. indoor temperature: 14.9 °C
# Max. indoor temperature: 20.6 °C
# Max. load: 156.0 W at 2000-02-04 08:00:00+01:00
# Energy consumption for heating: 11.5 kWh
# Energy consumption for cooling: -0.5 kWh
